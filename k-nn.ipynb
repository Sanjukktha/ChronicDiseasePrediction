# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ckd=pd.read_csv("final.csv")
y = ckd['Class']
# no feature seleection
#new_ckd = ckd.drop(['Class'], axis=1)
#correlation 
#new_ckd = ckd.drop(['Class','Age','Bp', 'Sg', 'Su','Rbc','Pcc','Ba','Sod','Pot','Wbcc','Pcv','Rbcc','Htn','Dm','Cad','Appet','pe','Ane'], axis=1)
#lasso 
#new_ckd = ckd.drop(['Class','Age', 'Bp', 'Pc', 'Pcc', 'Ba', 'Bu', 'Pot', 'Wbcc', 'Rbcc', 'Cad','Ane'], axis=1) 
#wrapper
new_ckd = ckd.drop(['Class','Age', 'Bp', 'Su', 'Pc', 'Pcc', 'Ba', 'Bgr', 'Bu', 'Sc', 'Sod', 'Pot', 'Hemo', 'Pcv', 'Wbcc', 'Rbcc', 'Htn', 'Cad', 'Appet', 'pe', 'Ane'], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(new_ckd, y, test_size=0.5, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
pred=knn.predict(X_test)
actuals=y_test.values.tolist()
print("Prediction "+" Output "+"Match")
for i in range(0,len(actuals)-1):
    print(pred[i],"         ",actuals[i],"     ",end="")
    if pred[i]==actuals[i]:
        print("Yes")
    else:
        print("No")


print('Accuracy of K-NN classifier on training set: {:.2f}'.format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'.format(knn.score(X_test, y_test)))
# Out:
# Prediction  Output Match
# 1           1      Yes
# 1           0      No
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           0      No
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           0      No
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           0      No
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 0           0      Yes
# 0           0      Yes
# 0           0      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 0           0      Yes
# 0           0      Yes
# 0           0      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 0           0      Yes
# 0           0      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 0           0      Yes
# 1           1      Yes
# 1           0      No
# 1           1      Yes
# 1           0      No
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           0      No
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           0      No
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# 0           0      Yes
# 1           1      Yes
# 0           0      Yes
# 0           0      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 1           1      Yes
# 0           0      Yes
# Accuracy of K-NN classifier on training set: 0.99
# Accuracy of K-NN classifier on test set: 0.96

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score 
newpred=pred.round()
newpred=abs(newpred)
precision=precision_score(y_test,newpred)
recall=recall_score(y_test,newpred)
f1=f1_score(y_test,newpred)
accuracy=accuracy_score(y_test,newpred)
auc=roc_auc_score(y_test,pred)
gini=(2*auc)-1
print("gini",gini)
print("Precision",precision*100)
print("Recall",recall*100)
print("f1 score",f1*100)
print("roc auc score",auc*100)
print("accuracy",accuracy*100)
# Out:
# gini 89.04109589041096
# Precision 94.07407407407408
# Recall 100.0
# f1 score 96.94656488549619
# roc auc score 94.52054794520548
# accuracy 96.0
